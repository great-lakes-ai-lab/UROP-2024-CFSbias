# %% [markdown]
# # DeepSensor QuickStart
#
# This material is from the DeepSensor QuickStart documentation from the GitHub page.
#
# Here we will demonstrate a simple example of training a convolutional conditional neural process (ConvCNP) to spatially interpolate random grid cells of NCEP reanalysis air temperature data over the US. First, pip install the package. In this case we will use the PyTorch backend (note: follow the PyTorch installation instructions if you want GPU support).
#
# Feel free to experiment by changing parameters, experimenting with different datasets, and so on! You can also try out any of the other material that you find in the DeepSensor documentation:
#
# https://alan-turing-institute.github.io/deepsensor/

# %% [markdown]
# ## Install required package
#
# DeepSensor is a pip installable package, which makes our job much easier

# %%
# !pip install deepsensor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepsensor in /home/dannes/.local/lib/python3.10/site-packages (0.3.6)
# Requirement already satisfied: pooch in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (1.4.0)
# Requirement already satisfied: backends in /home/dannes/.local/lib/python3.10/site-packages (from deepsensor) (1.6.1)
# Requirement already satisfied: distributed in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (2022.7.0)
# Requirement already satisfied: tqdm in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (4.64.1)
# Requirement already satisfied: backends-matrix in /home/dannes/.local/lib/python3.10/site-packages (from deepsensor) (1.3.0)
# Requirement already satisfied: xarray in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (2022.11.0)
# Requirement already satisfied: numpy in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (1.23.5)
# Requirement already satisfied: dask in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (2022.7.0)
# Requirement already satisfied: pyshp in /home/dannes/.local/lib/python3.10/site-packages (from deepsensor) (2.3.1)
# Requirement already satisfied: neuralprocesses in /home/dannes/.local/lib/python3.10/site-packages (from deepsensor) (0.2.4)
# Requirement already satisfied: seaborn in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (0.12.2)
# Requirement already satisfied: gcsfs in /home/dannes/.local/lib/python3.10/site-packages (from deepsensor) (2024.2.0)
# Requirement already satisfied: zarr in /home/dannes/.local/lib/python3.10/site-packages (from deepsensor) (2.17.0)
# Requirement already satisfied: pandas in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from deepsensor) (1.5.3)
# Requirement already satisfied: opt-einsum in /home/dannes/.local/lib/python3.10/site-packages (from backends->deepsensor) (3.3.0)
# Requirement already satisfied: scipy>=1.3 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from backends->deepsensor) (1.10.0)
# Requirement already satisfied: plum-dispatch>=2.3.2 in /home/dannes/.local/lib/python3.10/site-packages (from backends->deepsensor) (2.3.2)
# Requirement already satisfied: fdm in /home/dannes/.local/lib/python3.10/site-packages (from backends->deepsensor) (0.4.1)
# Requirement already satisfied: algebra in /home/dannes/.local/lib/python3.10/site-packages (from backends-matrix->deepsensor) (1.2.1)
# Requirement already satisfied: wbml>=0.3 in /home/dannes/.local/lib/python3.10/site-packages (from backends-matrix->deepsensor) (0.4.1)
# Requirement already satisfied: toolz>=0.8.2 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from dask->deepsensor) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from dask->deepsensor) (6.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from dask->deepsensor) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from dask->deepsensor) (22.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/dannes/.local/lib/python3.10/site-packages (from dask->deepsensor) (2024.2.0)
# Requirement already satisfied: partd>=0.3.10 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from dask->deepsensor) (1.2.0)
# Requirement already satisfied: tornado<6.2,>=6.0.3 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (6.1)
# Requirement already satisfied: click>=6.6 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (8.0.4)
# Requirement already satisfied: tblib>=1.6.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (1.7.0)
# Requirement already satisfied: jinja2 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (3.1.2)
# Requirement already satisfied: zict>=0.1.3 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (2.1.0)
# Requirement already satisfied: msgpack>=0.6.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (1.0.3)
# Requirement already satisfied: psutil>=5.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (5.9.0)
# Requirement already satisfied: urllib3 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (1.26.14)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (2.4.0)
# Requirement already satisfied: locket>=1.0.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from distributed->deepsensor) (1.0.0)
# Requirement already satisfied: requests in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from gcsfs->deepsensor) (2.28.1)
# Requirement already satisfied: decorator>4.1.2 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from gcsfs->deepsensor) (5.1.1)
# Requirement already satisfied: google-auth-oauthlib in /home/dannes/.local/lib/python3.10/site-packages (from gcsfs->deepsensor) (1.2.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/dannes/.local/lib/python3.10/site-packages (from gcsfs->deepsensor) (3.9.3)
# Requirement already satisfied: google-auth>=1.2 in /home/dannes/.local/lib/python3.10/site-packages (from gcsfs->deepsensor) (2.28.1)
# Requirement already satisfied: google-cloud-storage in /home/dannes/.local/lib/python3.10/site-packages (from gcsfs->deepsensor) (2.15.0)
# Requirement already satisfied: stheno>=1.3.10 in /home/dannes/.local/lib/python3.10/site-packages (from neuralprocesses->deepsensor) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from pandas->deepsensor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from pandas->deepsensor) (2022.7)
# Requirement already satisfied: appdirs in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from pooch->deepsensor) (1.4.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from seaborn->deepsensor) (3.7.0)
# Requirement already satisfied: fasteners in /home/dannes/.local/lib/python3.10/site-packages (from zarr->deepsensor) (0.19)
# Requirement already satisfied: asciitree in /home/dannes/.local/lib/python3.10/site-packages (from zarr->deepsensor) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/dannes/.local/lib/python3.10/site-packages (from zarr->deepsensor) (0.12.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/dannes/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/dannes/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/dannes/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/dannes/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/dannes/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (1.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/dannes/.local/lib/python3.10/site-packages (from google-auth>=1.2->gcsfs->deepsensor) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/dannes/.local/lib/python3.10/site-packages (from google-auth>=1.2->gcsfs->deepsensor) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from google-auth>=1.2->gcsfs->deepsensor) (0.2.8)
# Requirement already satisfied: contourpy>=1.0.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->deepsensor) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->deepsensor) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->deepsensor) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->deepsensor) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->deepsensor) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->deepsensor) (1.4.4)
# Requirement already satisfied: rich>=10.0 in /home/dannes/.local/lib/python3.10/site-packages (from plum-dispatch>=2.3.2->backends->deepsensor) (13.7.1)
# Requirement already satisfied: beartype>=0.16.2 in /home/dannes/.local/lib/python3.10/site-packages (from plum-dispatch>=2.3.2->backends->deepsensor) (0.17.2)
# Requirement already satisfied: typing-extensions in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from plum-dispatch>=2.3.2->backends->deepsensor) (4.4.0)
# Requirement already satisfied: six>=1.5 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->deepsensor) (1.16.0)
# Requirement already satisfied: mlkernels>=0.3.6 in /home/dannes/.local/lib/python3.10/site-packages (from stheno>=1.3.10->neuralprocesses->deepsensor) (0.4.0)
# Requirement already satisfied: pyarrow in /home/dannes/.local/lib/python3.10/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (15.0.0)
# Requirement already satisfied: varz>=0.6 in /home/dannes/.local/lib/python3.10/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (0.8.1)
# Requirement already satisfied: scikit-learn in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (1.2.1)
# Requirement already satisfied: netCDF4 in /home/dannes/.local/lib/python3.10/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (1.6.5)
# Requirement already satisfied: python-slugify in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (5.0.2)
# Requirement already satisfied: heapdict in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from zict>=0.1.3->distributed->deepsensor) (1.0.1)
# Requirement already satisfied: sympy in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from fdm->backends->deepsensor) (1.11.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/dannes/.local/lib/python3.10/site-packages (from google-auth-oauthlib->gcsfs->deepsensor) (1.3.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /home/dannes/.local/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->deepsensor) (2.4.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /home/dannes/.local/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->deepsensor) (2.17.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/dannes/.local/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->deepsensor) (1.5.0)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /home/dannes/.local/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->deepsensor) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from requests->gcsfs->deepsensor) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from requests->gcsfs->deepsensor) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from requests->gcsfs->deepsensor) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from jinja2->distributed->deepsensor) (2.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/dannes/.local/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs->deepsensor) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /home/dannes/.local/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs->deepsensor) (4.25.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs->deepsensor) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/dannes/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs->deepsensor) (3.2.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/dannes/.local/lib/python3.10/site-packages (from rich>=10.0->plum-dispatch>=2.3.2->backends->deepsensor) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/dannes/.local/lib/python3.10/site-packages (from rich>=10.0->plum-dispatch>=2.3.2->backends->deepsensor) (3.0.0)
# Requirement already satisfied: cftime in /home/dannes/.local/lib/python3.10/site-packages (from netCDF4->wbml>=0.3->backends-matrix->deepsensor) (1.6.3)
# Requirement already satisfied: text-unidecode>=1.3 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from python-slugify->wbml>=0.3->backends-matrix->deepsensor) (1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from scikit-learn->wbml>=0.3->backends-matrix->deepsensor) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages (from scikit-learn->wbml>=0.3->backends-matrix->deepsensor) (1.1.1)
# Requirement already satisfied: mpmath>=0.19 in /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->fdm->backends->deepsensor) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /home/dannes/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch>=2.3.2->backends->deepsensor) (0.1.2)

# %% [markdown]
# ## Load required packages
#
# This includes aspects of deepsensor, as well as xarray, pandas, numpy, and tqdm.

# %%
import deepsensor.torch
from deepsensor.data import DataProcessor, TaskLoader
from deepsensor.model import ConvNP
from deepsensor.train import Trainer

import xarray as xr
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## Load context dataset
#
# DeepSensor comes pre-packaged with some tutorial datasets, including an air temperature dataset that covers North America.

# %%
# Load raw data
ds_raw = xr.tutorial.open_dataset("air_temperature")
print(ds_raw)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, time: 2920, lon: 53)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ## Normalize the data
#
# Next we create an instance of the DataProcessor class, which handles the normalization of xarray and pandas data for DeepSensor models.
#
# https://alan-turing-institute.github.io/deepsensor/reference/data/processor.html

# %%
# Normalise data
data_processor = DataProcessor(x1_name="lat", x2_name="lon")
ds = data_processor(ds_raw)
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:  (x1: 25, time: 2920, x2: 53)
# Coordinates:
#   * x1       (x1) float32 0.4615 0.4423 0.4231 0.4038 ... 0.03846 0.01923 0.0
#   * x2       (x2) float32 0.0 0.01923 0.03846 0.05769 ... 0.9615 0.9808 1.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, x1, x2) float32 -2.456 -2.377 -2.315 ... 0.9159 0.8852
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ## Get the task loader ready
#
# Here we create an instance of the TaskLoader class, which provides a suite of sampling methods for generating Task objects for different kinds of predictions, such as: spatial interpolation, forecasting, downscaling, or some combination of these. Notice that the TaskLoader is defined by the context set and the target set, which consist of sets of variables with dimensions.
#
# https://alan-turing-institute.github.io/deepsensor/reference/data/loader.html

# %%
# Set up task loader
task_loader = TaskLoader(context=ds, target=ds)
task_loader
# Out:
# TaskLoader(1 context sets, 1 target sets)
# Context variable IDs: (('air',),)
# Target variable IDs: (('air',),)
#
# Context data dimensions: (1,)
# Target data dimensions: (1,)

# %% [markdown]
# ## Creating the ConvNP model
#
# There are a number of different possible modeling approaches. Here we are using the convolutional neural process regression model:
#
# https://alan-turing-institute.github.io/deepsensor/reference/model/convnp.html

# %%
# Set up model
model = ConvNP(data_processor, task_loader)
model
# Out:
# dim_yc inferred from TaskLoader: (1,)
# dim_yt inferred from TaskLoader: 1
# dim_aux_t inferred from TaskLoader: 0
# internal_density inferred from TaskLoader: 52
# encoder_scales inferred from TaskLoader: [0.009615384042263031]
# decoder_scale inferred from TaskLoader: 0.019230769230769232

# %% [markdown]
# ## Generate training tasks
#
# Our context set consists of values from 100 random grid cells in the date range indicated below. The `task_loader` that we created above can then be used to generate the individual training tasks.

# %%
# Generate training tasks with up 100 grid cells as context and all grid cells
#   as targets
train_tasks = []
for date in pd.date_range("2013-01-01", "2014-11-30")[::7]:
    N_context = np.random.randint(0, 100)
    task = task_loader(date, context_sampling=N_context, target_sampling="all")
    train_tasks.append(task)
    
train_tasks
# Out:
# [time: Timestamp/2013-01-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 29)']
#  Y_c: ['ndarray/float32/(1, 29)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 5)']
#  Y_c: ['ndarray/float32/(1, 5)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 60)']
#  Y_c: ['ndarray/float32/(1, 60)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 54)']
#  Y_c: ['ndarray/float32/(1, 54)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 80)']
#  Y_c: ['ndarray/float32/(1, 80)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 12)']
#  Y_c: ['ndarray/float32/(1, 12)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 7)']
#  Y_c: ['ndarray/float32/(1, 7)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 25)']
#  Y_c: ['ndarray/float32/(1, 25)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 9)']
#  Y_c: ['ndarray/float32/(1, 9)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 66)']
#  Y_c: ['ndarray/float32/(1, 66)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 60)']
#  Y_c: ['ndarray/float32/(1, 60)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 7)']
#  Y_c: ['ndarray/float32/(1, 7)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 32)']
#  Y_c: ['ndarray/float32/(1, 32)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-02 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 3)']
#  Y_c: ['ndarray/float32/(1, 3)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-09 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 15)']
#  Y_c: ['ndarray/float32/(1, 15)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-16 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 14)']
#  Y_c: ['ndarray/float32/(1, 14)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-23 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 64)']
#  Y_c: ['ndarray/float32/(1, 64)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-30 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 50)']
#  Y_c: ['ndarray/float32/(1, 50)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-07 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 98)']
#  Y_c: ['ndarray/float32/(1, 98)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-14 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 52)']
#  Y_c: ['ndarray/float32/(1, 52)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-21 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 69)']
#  Y_c: ['ndarray/float32/(1, 69)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-28 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 39)']
#  Y_c: ['ndarray/float32/(1, 39)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 60)']
#  Y_c: ['ndarray/float32/(1, 60)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 47)']
#  Y_c: ['ndarray/float32/(1, 47)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 98)']
#  Y_c: ['ndarray/float32/(1, 98)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 6)']
#  Y_c: ['ndarray/float32/(1, 6)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-02 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 77)']
#  Y_c: ['ndarray/float32/(1, 77)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-09 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 44)']
#  Y_c: ['ndarray/float32/(1, 44)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-16 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 84)']
#  Y_c: ['ndarray/float32/(1, 84)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-23 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 76)']
#  Y_c: ['ndarray/float32/(1, 76)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-30 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 19)']
#  Y_c: ['ndarray/float32/(1, 19)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-06 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 50)']
#  Y_c: ['ndarray/float32/(1, 50)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-13 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 92)']
#  Y_c: ['ndarray/float32/(1, 92)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-20 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 92)']
#  Y_c: ['ndarray/float32/(1, 92)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-27 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 64)']
#  Y_c: ['ndarray/float32/(1, 64)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-03 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 43)']
#  Y_c: ['ndarray/float32/(1, 43)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-10 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 12)']
#  Y_c: ['ndarray/float32/(1, 12)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-17 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 72)']
#  Y_c: ['ndarray/float32/(1, 72)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-24 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 50)']
#  Y_c: ['ndarray/float32/(1, 50)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 12)']
#  Y_c: ['ndarray/float32/(1, 12)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 72)']
#  Y_c: ['ndarray/float32/(1, 72)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 71)']
#  Y_c: ['ndarray/float32/(1, 71)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 43)']
#  Y_c: ['ndarray/float32/(1, 43)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 59)']
#  Y_c: ['ndarray/float32/(1, 59)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 92)']
#  Y_c: ['ndarray/float32/(1, 92)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 53)']
#  Y_c: ['ndarray/float32/(1, 53)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 81)']
#  Y_c: ['ndarray/float32/(1, 81)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 18)']
#  Y_c: ['ndarray/float32/(1, 18)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-03 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 55)']
#  Y_c: ['ndarray/float32/(1, 55)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-10 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 21)']
#  Y_c: ['ndarray/float32/(1, 21)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-17 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 44)']
#  Y_c: ['ndarray/float32/(1, 44)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-24 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 87)']
#  Y_c: ['ndarray/float32/(1, 87)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-31 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 41)']
#  Y_c: ['ndarray/float32/(1, 41)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-07 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 81)']
#  Y_c: ['ndarray/float32/(1, 81)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-14 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 9)']
#  Y_c: ['ndarray/float32/(1, 9)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-21 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 28)']
#  Y_c: ['ndarray/float32/(1, 28)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-28 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 9)']
#  Y_c: ['ndarray/float32/(1, 9)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 50)']
#  Y_c: ['ndarray/float32/(1, 50)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 3)']
#  Y_c: ['ndarray/float32/(1, 3)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 39)']
#  Y_c: ['ndarray/float32/(1, 39)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 21)']
#  Y_c: ['ndarray/float32/(1, 21)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 80)']
#  Y_c: ['ndarray/float32/(1, 80)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 85)']
#  Y_c: ['ndarray/float32/(1, 85)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 51)']
#  Y_c: ['ndarray/float32/(1, 51)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 87)']
#  Y_c: ['ndarray/float32/(1, 87)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 83)']
#  Y_c: ['ndarray/float32/(1, 83)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 59)']
#  Y_c: ['ndarray/float32/(1, 59)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 29)']
#  Y_c: ['ndarray/float32/(1, 29)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 78)']
#  Y_c: ['ndarray/float32/(1, 78)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 84)']
#  Y_c: ['ndarray/float32/(1, 84)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-06 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 67)']
#  Y_c: ['ndarray/float32/(1, 67)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-13 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 16)']
#  Y_c: ['ndarray/float32/(1, 16)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-20 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 93)']
#  Y_c: ['ndarray/float32/(1, 93)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-27 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 86)']
#  Y_c: ['ndarray/float32/(1, 86)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-03 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 98)']
#  Y_c: ['ndarray/float32/(1, 98)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-10 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 38)']
#  Y_c: ['ndarray/float32/(1, 38)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-17 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 22)']
#  Y_c: ['ndarray/float32/(1, 22)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-24 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 57)']
#  Y_c: ['ndarray/float32/(1, 57)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 83)']
#  Y_c: ['ndarray/float32/(1, 83)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 7)']
#  Y_c: ['ndarray/float32/(1, 7)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 69)']
#  Y_c: ['ndarray/float32/(1, 69)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 43)']
#  Y_c: ['ndarray/float32/(1, 43)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 32)']
#  Y_c: ['ndarray/float32/(1, 32)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 84)']
#  Y_c: ['ndarray/float32/(1, 84)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 88)']
#  Y_c: ['ndarray/float32/(1, 88)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 37)']
#  Y_c: ['ndarray/float32/(1, 37)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 10)']
#  Y_c: ['ndarray/float32/(1, 10)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-02 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 86)']
#  Y_c: ['ndarray/float32/(1, 86)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-09 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 91)']
#  Y_c: ['ndarray/float32/(1, 91)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-16 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 70)']
#  Y_c: ['ndarray/float32/(1, 70)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-23 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 59)']
#  Y_c: ['ndarray/float32/(1, 59)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-30 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 62)']
#  Y_c: ['ndarray/float32/(1, 62)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-07 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 86)']
#  Y_c: ['ndarray/float32/(1, 86)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-14 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 30)']
#  Y_c: ['ndarray/float32/(1, 30)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-21 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 89)']
#  Y_c: ['ndarray/float32/(1, 89)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-28 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 90)']
#  Y_c: ['ndarray/float32/(1, 90)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 46)']
#  Y_c: ['ndarray/float32/(1, 46)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 95)']
#  Y_c: ['ndarray/float32/(1, 95)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 83)']
#  Y_c: ['ndarray/float32/(1, 83)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 49)']
#  Y_c: ['ndarray/float32/(1, 49)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)']]

# %% [markdown]
# ## Train the model
#
# The Trainer class will actually carry out the training of the ConvNP model, using the tasks generated above. (Note that the hyperparameter `lr` is a learning rate - I misremembered it as a regularization parameter.)
#
# https://alan-turing-institute.github.io/deepsensor/reference/train/train.html

# %%
# Train model
trainer = Trainer(model, lr=5e-5)
for epoch in tqdm(range(10)):
    batch_losses = trainer(train_tasks)
# Out:
# 100%|██████████| 10/10 [04:18<00:00, 25.81s/it]

# %% [markdown]
# ## Make a prediction using the fitted ConvNP model
#
# Finally, we can create a testing/prediction task to predict the air temperature on a date that was excluded from the training data. Note that the model outputs mean and standard deviation.
#
# https://alan-turing-institute.github.io/deepsensor/reference/model/pred.html

# %%
# Predict on new task with 50 context points and a dense grid of target points
test_task = task_loader("2014-12-31", context_sampling=50)
pred = model.predict(test_task, X_t=ds_raw)
pred["air"]
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 25, lon: 53)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-12-31
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
# Data variables:
#     mean     (time, lat, lon) float32 254.3 253.6 252.5 ... 298.5 298.3 298.1
#     std      (time, lat, lon) float32 11.86 11.61 10.89 ... 2.17 2.272 2.365
